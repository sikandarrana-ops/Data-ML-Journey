# %%
#Task 3 to 14
print("task 3 to 14")
# Out:
# task 3 to 14

# %%
#Task 3
#this programe add two numbers

num1 = 1.5
num2 = 6.3

#add two numbers
sum = num1 + num2

#display the sum
print('the sum of {0} and {1} is {2}'.format(num1,num2,sum))
# Out:
# the sum of 1.5 and 6.3 is 7.8

# %%
#Task 4
#num1 = input("Enter the first number: ")
#num2 = input("Enter the second number: ")
num1=2.5
num2=5.6
#add two numbers
sum = float(num1) + float(num2)
#display the sum
print('the sum of {0} and {1} is {2}'.format(num1,num2,sum))
# Out:
# the sum of 2.5 and 5.6 is 8.1

# %%
#Task 5
#python program to calculate the square root
# note change this value for different results

num = 8
#to take the input from user
#num=float(input("Enter a number: "))
num_sqrt = num ** 0.5
print('The square root of %0.3f is %0.3f', (num,num_sqrt))
# Out:
# The square root of %0.3f is %0.3f (8, 2.8284271247461903)

# %%
#task 6
#Find square root of real or complex numbers
#importing the complex math module
import cmath
num = 1+2j
#to take input from the user
#num=eval(input("enter a number"))
num_sqrt = cmath.sqrt(num)
print("the square root of {0} is {1:0.3f}+{2:0.3f}j".format(num,num_sqrt.real,num_sqrt.imag))
# Out:
# the square root of (1+2j) is 1.272+0.786j

# %%
#task 7
#python program to convert temperature in celsius to farenheit

#chnage this value for different results
celsius = 37.5
#calculate farenheit

farenheite = (celsius * 1.8) + 32
print("%0.1f degree celsius is equal to %0.1f dagree farenheit", (celsius,farenheite))
# Out:
# %0.1f degree celsius is equal to %0.1f dagree farenheit (37.5, 99.5)

# %%
#task 8
#python program to find the area of triangle

#a = float(input("enter first side: "))
#b = float(input("enter second side: "))
#c = float(input("enter third side: "))

a = 5
b = 6
c = 7
#calculate the semi perimeter

s = (a + b + c) / 2
#calculate the area
area = (s*(s-a)*(s-b)*(s-c))**0.5
print('the area of triangle is %0.2f' %area)
# Out:
# the area of triangle is 14.70

# %%
#task 9
#solve the quadratic equation ax**2 + bx + c = 0
# import complex math module
import cmath

a = 1
b = 5
c = 6
# calculate the discriminant 
d = (b**2) - (4*a*c)
#find two solutions
sol1 = (-b-cmath.sqrt(d))/(2*a)
sol2 = (-b+cmath.sqrt(d))/(2*a)
print("the solutions are {0} and {1}".format(sol1,sol2))
# Out:
# the solutions are (-3+0j) and (-2+0j)

# %%
#task 10

#taking kilometers input from the user
kilometers = float(input("Enter value in kilometers: "))
#conversion factor
conv_fac = 0.621371
#calculate miles
miles = kilometers * conv_fac
print("miles", miles)
# Out:
# miles 6.21371

# %%
#task 11
i = 10
if (i > 15):
    print("10 is less than 15")

print("i'm not in if")
# Out:
# i'm not in if

# %%
#task 12
i = 20
if (i < 15):
    print("i is smaller than 15")
    print("I'm in if")

else:
    print("i is greater than 15")
    print("I'm in else block")
print("I'm not in If and Not in Else block")
# Out:
# i is greater than 15
# I'm in else block
# I'm not in If and Not in Else block

# %%
#Tasl 13
i = 10
if(i == 10):
    #first if statement
    if(i < 15):
        print("i is smaller than 15")
        #nested if statement
        #it will be execute if the first if statement is true
    if(i < 12):
        print("i is smaller than 12 too")
    else:
        print("i is greater than 15")
# Out:
# i is smaller than 15
# i is smaller than 12 too

# %%
#task 14
i = 20
if(i == 10):
    print("i is 10")
elif(i == 15):
    print("i is 15")
elif(i == 20):
    print("i is 20")
else:
    print("i is not present")
# Out:
# i is 20
